# %%
import sounddevice as sd
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
import sounddevice as sd
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft


gain = 10
duration = 0.1 # sample record duration
sample_rate = 44100
device = ('Microphone (Sound Blaster Play!, MME',
                       'Speakers (Sound Blaster Play! 3, MME')
sd.query_devices(device[0])
sd.default.device = device
sd.default.channels = 1
sd.default.samplerate = sample_rate

x4 = np.full(3528, 0.0)
for i in range(0, average):
    x1 = sd.rec(int(self.duration*self.sample_rate), dtype='float32', blocking=True) # record 0.1 seconds input signal from microphone

    x2 = self.gain*x1[int(self.duration*self.sample_rate/1000):int(self.duration*self.sample_rate)] # take effective samples

    x3 = x2[0:int(80*(self.sample_rate/1000))] # take first 80ms duration samples

    x4 += x3.flatten()# transfer 2D array to 1D, ready for fft operation, fft function can only take 1D array as input

x4 = x4 / average
t = 80*np.linspace(0, 1, np.size(x4))# generate 80ms time axis VS samples for first 80ms

X = fft(x4) # fft transform
n = np.size(t)

fr = (self.sample_rate/2)*np.linspace(0, 1, int(n/2)) # generate frequecny axis array

X_m = (2/n)*abs(X[0:np.size(fr)])

    

print(np.size(X_m))
# print(np.size(X_m[20:]))
# print(X_m[20:])
X_mmax = np.max(X_m)
fr_index = np.where(X_m  == X_mmax)
fr_max = fr[fr_index]
print(X_mmax)
print(fr_max)
print(fr_index)

mask = np.full(np.size(fr), 1)
mask[fr_index[0]]=0 
for i in range(1,130): 
    mask[fr_index[0]-i]=0
    mask[fr_index[0]+i]=0
        
SND = np.sum(X_m[24:240])
print(SND)
ND = np.sum(X_m[24:240] * mask[24:240])
print(ND)

# SND = np.sum(X_m)
# print(SND)
# ND = np.sum(X_m * mask)
# print(ND)

SINAD = 20 * np.log10(SND/ND)

print(SINAD)
# Out:
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 4410
# 4406
# 3528
# 3528
# 1764
# 10.646194
# [1000.56721497]
# (array([80], dtype=int64),)
# 18.307201
# 1.08263929374516
# 24.562763469076515
